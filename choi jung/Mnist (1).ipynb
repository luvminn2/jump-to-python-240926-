# %%
import numpy as np

# %% [markdown]
# import numpy as np는 파이썬에서 numpy 라이브러리를 np라는 이름으로 불러오는 코드입니다. numpy는 수치 계산을 위한 파이썬 라이브러리로, 배열, 행렬, 수학적 함수 등을 지원합니다. np는 numpy 라이브러리를 간편하게 사용할 수 있도록 줄여서 사용하기 위한 약칭입니다.

# %%
class Mnist_model:
    def __init__(self, X_train, Y_train,lr=0.1 ,epoch=1000):
        self.lr = lr
        self.epoch = epoch
        self.X_train = X_train
        self.Y_train = Y_train
        self.input_size = 784  # 입력층 노드 수
        self.hidden_layer1_size = 50  # 첫 번째 은닉층 노드 수
        self.hidden_layer2_size = 100  # 두 번째 은닉층 노드 수
        self.output_size = 10  # 출력층 노드 수
        self.w1 = np.random.randn(self.input_size, self.hidden_layer1_size) * np.sqrt(2. / self.input_size)
        self.w2 = np.random.randn(self.hidden_layer1_size, self.hidden_layer2_size) * np.sqrt(2. / self.hidden_layer1_size)
        self.w3 = np.random.randn(self.hidden_layer2_size, self.output_size) * np.sqrt(2. / self.hidden_layer2_size)
        self.b1 = np.zeros((1, self.hidden_layer1_size))
        self.b2 = np.zeros((1, self.hidden_layer2_size))
        self.b3 = np.zeros((1, self.output_size))

    def relu(self,x):
        return np.maximum(0, x)

    def relu_derivative(self,x):
        return (x > 0).astype(float)

    def softmax(self,x):
        exp_x = np.exp(x - np.max(x, axis=1, keepdims=True))
        return exp_x / np.sum(exp_x, axis=1, keepdims=True)

    def cross_entropy_loss(self,y_true, y_pred):
        return -np.mean(np.sum(y_true * np.log(y_pred + 1e-9), axis=1))
    
    def Laerning(self):
        for ep in range(self.epoch):
            # 순전파
            z1 = np.dot(self.X_train, self.w1) + self.b1
            a1 = self.relu(z1)  # ReLU 함수 사용
            z2 = np.dot(a1, self.w2) + self.b2
            a2 = self.relu(z2)  # ReLU 함수 사용
            z3 = np.dot(a2, self.w3) + self.b3
            a3 = self.softmax(z3)
            # 손실 계산
            loss = self.cross_entropy_loss(self.Y_train, a3)
            # 역전파
            dL_da3 = a3 - self.Y_train
            dL_dw3 = np.dot(a2.T, dL_da3) / self.X_train.shape[0]
            dL_db3 = np.sum(dL_da3, axis=0, keepdims=True) / self.X_train.shape[0]

            dL_da2 = np.dot(dL_da3, self.w3.T) * self.relu_derivative(a2)  # ReLU 미분 사용
            dL_dw2 = np.dot(a1.T, dL_da2) / self.X_train.shape[0]
            dL_db2 = np.sum(dL_da2, axis=0, keepdims=True) / self.X_train.shape[0]

            dL_da1 = np.dot(dL_da2, self.w2.T) * self.relu_derivative(a1)  # ReLU 미분 사용
            dL_dw1 = np.dot(self.X_train.T, dL_da1) / self.X_train.shape[0]
            dL_db1 = np.sum(dL_da1, axis=0, keepdims=True) / self.X_train.shape[0]


            # 가중치 및 바이어스 업데이트
            self.w3 -= self.lr * dL_dw3
            self.b3 -= self.lr * dL_db3
            self.w2 -= self.lr * dL_dw2
            self.b2 -= self.lr * dL_db2
            self.w1 -= self.lr * dL_dw1
            self.b1 -= self.lr * dL_db1

            # 에폭마다 손실 출력
            #if epoch % 100 == 0:
            print(f"Epoch {ep}, Loss: {loss:.4f}")
            
    # 모델 평가
    def evaluate(self,X_test, y_test):
        z1 = np.dot(X_test, self.w1) + self.b1
        a1 = self.relu(z1)
        z2 = np.dot(a1, self.w2) + self.b2
        a2 = self.relu(z2)
        z3 = np.dot(a2, self.w3) + self.b3
        a3 = self.relu(z3)

        predictions = np.argmax(a3, axis=1)
        accuracy = np.mean(predictions == np.argmax(y_test, axis=1))
        return accuracy

# %% [markdown]
# python
# 코드 복사
# class Mnist_model:
# Mnist_model이라는 이름의 클래스를 정의합니다.
# python
# 코드 복사
#     def __init__(self, X_train, Y_train, lr=0.1, epoch=1000):
# 클래스의 초기화 메서드 __init__를 정의합니다. X_train과 Y_train은 훈련 데이터와 레이블, lr은 학습률, epoch는 에폭 수를 의미합니다.
# python
# 코드 복사
#         self.lr = lr
#         self.epoch = epoch
#         self.X_train = X_train
#         self.Y_train = Y_train
# 초기화 메서드에서 학습률(lr), 에폭 수(epoch), 훈련 데이터(X_train), 훈련 레이블(Y_train)을 클래스의 인스턴스 변수로 저장합니다.
# python
# 코드 복사
#         self.input_size = 784  # 입력층 노드 수
#         self.hidden_layer1_size = 50  # 첫 번째 은닉층 노드 수
#         self.hidden_layer2_size = 100  # 두 번째 은닉층 노드 수
#         self.output_size = 10  # 출력층 노드 수
# 입력층, 첫 번째 은닉층, 두 번째 은닉층, 출력층의 노드 수를 정의합니다.
# python
# 코드 복사
#         self.w1 = np.random.randn(self.input_size, self.hidden_layer1_size) * np.sqrt(2. / self.input_size)
#         self.w2 = np.random.randn(self.hidden_layer1_size, self.hidden_layer2_size) * np.sqrt(2. / self.hidden_layer1_size)
#         self.w3 = np.random.randn(self.hidden_layer2_size, self.output_size) * np.sqrt(2. / self.hidden_layer2_size)
# 각 층의 가중치를 랜덤하게 초기화합니다. He 초기화(He initialization) 방법을 사용하여 분산을 조절합니다.
# python
# 코드 복사
#         self.b1 = np.zeros((1, self.hidden_layer1_size))
#         self.b2 = np.zeros((1, self.hidden_layer2_size))
#         self.b3 = np.zeros((1, self.output_size))
# 각 층의 바이어스를 0으로 초기화합니다.
# python
# 코드 복사
#     def relu(self, x):
#         return np.maximum(0, x)
# ReLU(정류화 선형 유닛) 활성화 함수를 정의합니다. 입력이 0보다 크면 그대로 반환하고, 0 이하이면 0으로 반환합니다.
# python
# 코드 복사
#     def relu_derivative(self, x):
#         return (x > 0).astype(float)
# ReLU 함수의 미분을 정의합니다. 입력이 0보다 크면 1, 그렇지 않으면 0을 반환합니다.
# python
# 코드 복사
#     def softmax(self, x):
#         exp_x = np.exp(x - np.max(x, axis=1, keepdims=True))
#         return exp_x / np.sum(exp_x, axis=1, keepdims=True)
# Softmax 활성화 함수를 정의합니다. 각 클래스의 확률을 반환합니다.
# python
# 코드 복사
#     def cross_entropy_loss(self, y_true, y_pred):
#         return -np.mean(np.sum(y_true * np.log(y_pred + 1e-9), axis=1))
# 교차 엔트로피 손실 함수를 정의합니다. 모델의 예측 값(y_pred)과 실제 레이블(y_true)을 비교하여 손실 값을 계산합니다.
# python
# 코드 복사
#     def Laerning(self):
# Laerning 메서드는 신경망을 학습시키는 메서드입니다. (Laerning은 아마도 Learning의 오타일 것 같습니다.)
# python
# 코드 복사
#         for ep in range(self.epoch):
# 지정된 에폭 수만큼 반복합니다.
# python
# 코드 복사
#             z1 = np.dot(self.X_train, self.w1) + self.b1
#             a1 = self.relu(z1)  # ReLU 함수 사용
# 입력 데이터와 첫 번째 층의 가중치 행렬을 곱하고 바이어스를 더한 후 ReLU 함수를 적용합니다.
# python
# 코드 복사
#             z2 = np.dot(a1, self.w2) + self.b2
#             a2 = self.relu(z2)  # ReLU 함수 사용
# 첫 번째 은닉층의 출력을 두 번째 층에 입력하여 가중치와 바이어스를 적용한 후 ReLU 함수를 적용합니다.
# python
# 코드 복사
#             z3 = np.dot(a2, self.w3) + self.b3
#             a3 = self.softmax(z3)
# 두 번째 은닉층의 출력을 출력층에 입력하여 가중치와 바이어스를 적용한 후 Softmax 함수를 적용하여 확률 분포를 얻습니다.
# python
# 코드 복사
#             loss = self.cross_entropy_loss(self.Y_train, a3)
# 예측 값과 실제 레이블을 사용하여 손실 값을 계산합니다.
# python
# 코드 복사
#             dL_da3 = a3 - self.Y_train
#             dL_dw3 = np.dot(a2.T, dL_da3) / self.X_train.shape[0]
#             dL_db3 = np.sum(dL_da3, axis=0, keepdims=True) / self.X_train.shape[0]
# 출력층의 기울기를 계산하고, 가중치와 바이어스의 기울기를 계산합니다.
# python
# 코드 복사
#             dL_da2 = np.dot(dL_da3, self.w3.T) * self.relu_derivative(a2)  # ReLU 미분 사용
#             dL_dw2 = np.dot(a1.T, dL_da2) / self.X_train.shape[0]
#             dL_db2 = np.sum(dL_da2, axis=0, keepdims=True) / self.X_train.shape[0]
# 두 번째 은닉층의 기울기를 계산하고, 가중치와 바이어스의 기울기를 계산합니다.
# python
# 코드 복사
#             dL_da1 = np.dot(dL_da2, self.w2.T) * self.relu_derivative(a1)  # ReLU 미분 사용
#             dL_dw1 = np.dot(self.X_train.T, dL_da1) / self.X_train.shape[0]
#             dL_db1 = np.sum(dL_da1, axis=0, keepdims=True) / self.X_train.shape[0]
# 첫 번째 은닉층의 기울기를 계산하고, 가중치와 바이어스의 기울기를 계산합니다.
# python
# 코드 복사
#             self.w3 -= self.lr * dL_dw3
#             self.b3 -= self.lr * dL_db3
#             self.w2 -= self.lr * dL_dw2
#             self.b2 -= self.lr * dL_db2
#             self.w1 -= self.lr * dL_dw1
#             self.b1 -= self.lr * dL_db1
# 가중치와 바이어스를 학습률(lr)에 기울기를 곱한 만큼 업데이트합니다.
# python
# 코드 복사
#             print(f"Epoch {ep}, Loss: {loss:.4f}")
# 매 에폭마다 손실 값을 출력합니다.
# python
# 코드 복사
#     def evaluate(self, X_test, y_test):
# 모델 평가를 위한 evaluate 메서드를 정의합니다. X_test는 테스트 데이터, y_test는 테스트 레이블입니다.
# python
# 코드 복사
#         z1 = np.dot(X_test, self.w1) + self.b1
#         a1 = self.relu(z1)
#         z2 = np.dot(a1, self.w2) + self.b2
#         a2 = self.relu(z2)
#         z3 = np.dot(a2, self.w3) + self.b3
#         a3 = self.softmax(z3)
# 테스트 데이터에 대해 순전파를 수행하여 예측 결과를 얻습니다.
# python
# 코드 복사
#         predictions = np.argmax(a3, axis=1)
#         accuracy = np.mean(predictions == np.argmax(y_test, axis=1))
#         return accuracy
# 예측 결과의 클래스 인덱스를 찾고, 이와 실제 레이블의 클래스 인덱스를 비교하여 정확도를 계산한 후 반환합니다.

# %%
# idx 형식 파일 읽기 함수
def load_idx_file(filename):
    with open(filename, 'rb') as f:
        # 파일 헤더 부분 읽기
        magic_number = int.from_bytes(f.read(4), byteorder='big')
        if magic_number == 2051:  # 이미지 파일
            num_images = int.from_bytes(f.read(4), byteorder='big')
            rows = int.from_bytes(f.read(4), byteorder='big')
            cols = int.from_bytes(f.read(4), byteorder='big')
            data = np.frombuffer(f.read(), dtype=np.uint8).reshape(num_images, rows * cols)
        elif magic_number == 2049:  # 레이블 파일
            num_labels = int.from_bytes(f.read(4), byteorder='big')
            data = np.frombuffer(f.read(), dtype=np.uint8)
        else:
            raise ValueError(f"Wrong File: {filename}")
    return data

# %% [markdown]
# 이 함수는 IDX 형식의 파일을 읽어 numpy 배열로 변환하는 역할을 합니다. IDX 형식은 주로 MNIST 데이터셋에서 사용되는 파일 형식입니다. 한 줄씩 해석해보겠습니다.
#
# python
# 코드 복사
# def load_idx_file(filename):
# load_idx_file이라는 이름의 함수를 정의합니다. 이 함수는 filename이라는 파일 이름을 인자로 받아 해당 파일을 읽습니다.
# python
# 코드 복사
#     with open(filename, 'rb') as f:
# filename을 바이너리 모드('rb')로 열어 파일 객체 f를 생성합니다. with 문을 사용하여 파일을 열면 파일 작업이 끝난 후 자동으로 파일이 닫힙니다.
# python
# 코드 복사
#         magic_number = int.from_bytes(f.read(4), byteorder='big')
# 파일의 처음 4바이트를 읽어 magic_number라는 변수에 저장합니다. magic_number는 파일의 유형을 식별하는 데 사용됩니다. int.from_bytes를 사용하여 바이트 데이터를 정수로 변환합니다. byteorder='big'은 바이트 순서가 빅 엔디안임을 의미합니다.
# python
# 코드 복사
#         if magic_number == 2051:  # 이미지 파일
# magic_number가 2051인 경우, 이는 이미지 파일이라는 의미입니다.
# python
# 코드 복사
#             num_images = int.from_bytes(f.read(4), byteorder='big')
#             rows = int.from_bytes(f.read(4), byteorder='big')
#             cols = int.from_bytes(f.read(4), byteorder='big')
# 이미지 파일인 경우, 다음 12바이트를 읽어 각각 num_images (이미지 개수), rows (이미지의 행 수), cols (이미지의 열 수) 변수에 저장합니다.
# python
# 코드 복사
#             data = np.frombuffer(f.read(), dtype=np.uint8).reshape(num_images, rows * cols)
# 파일의 나머지 부분을 읽어 data 변수에 저장합니다. np.frombuffer를 사용하여 바이너리 데이터를 uint8 타입의 numpy 배열로 변환합니다. 이후 reshape을 사용하여 (num_images, rows * cols) 형태로 배열을 재구성합니다.
# python
# 코드 복사
#         elif magic_number == 2049:  # 레이블 파일
# magic_number가 2049인 경우, 이는 레이블 파일이라는 의미입니다.
# python
# 코드 복사
#             num_labels = int.from_bytes(f.read(4), byteorder='big')
#             data = np.frombuffer(f.read(), dtype=np.uint8)
# 레이블 파일인 경우, 다음 4바이트를 읽어 num_labels (레이블 개수) 변수에 저장한 후, 파일의 나머지 부분을 data 변수에 저장합니다. 이 데이터는 uint8 타입의 numpy 배열로 변환됩니다.
# python
# 코드 복사
#         else:
#             raise ValueError(f"Wrong File: {filename}")
# magic_number가 2051도 2049도 아닌 경우, 파일 형식이 잘못되었다고 판단하여 ValueError를 발생시킵니다.
# python
# 코드 복사
#     return data
# 읽어온 데이터를 반환합니다. 이미지 파일의 경우 (num_images, rows * cols) 형태의 배열, 레이블 파일의 경우 (num_labels,) 형태의 배열이 반환됩니다.

# %%
# 원-핫 인코딩 함수
def one_hot_encode(y, num_classes):
    return np.eye(num_classes)[y]

# %% [markdown]
# one_hot_encode 함수는 주어진 레이블을 원-핫 인코딩(One-Hot Encoding) 형식으로 변환합니다. 이 함수는 다음과 같이 동작합니다.
#
# python
# 코드 복사
# def one_hot_encode(y, num_classes):
# one_hot_encode라는 함수를 정의합니다. 이 함수는 두 개의 인자를 받습니다:
# y: 원-핫 인코딩할 레이블 배열입니다. 레이블은 정수로 이루어진 배열이어야 합니다.
# num_classes: 총 클래스의 개수입니다. 이 값은 원-핫 인코딩 배열의 열 수를 결정합니다.
# python
# 코드 복사
#     return np.eye(num_classes)[y]
# np.eye(num_classes)는 num_classes x num_classes 크기의 단위 행렬(identity matrix)을 생성합니다. 단위 행렬은 대각선의 요소가 1이고 나머지 요소가 0인 행렬입니다.
# np.eye(num_classes)[y]는 y의 값에 따라 단위 행렬의 특정 행을 선택합니다. y는 각 레이블을 나타내는 정수 배열이므로, 각 정수는 단위 행렬에서 해당하는 행을 선택하는 인덱스로 사용됩니다.
# 예를 들어, num_classes=3이고 y=[0, 2, 1]일 경우, np.eye(num_classes)는 다음과 같은 3x3 단위 행렬을 생성합니다:
# lua
# 코드 복사
# [[1., 0., 0.],
#  [0., 1., 0.],
#  [0., 0., 1.]]
# np.eye(num_classes)[y]는 이 단위 행렬에서 y의 값(0, 2, 1)에 해당하는 행들을 선택하여 원-핫 인코딩된 배열을 생성합니다:
# lua
# 코드 복사
# [[1., 0., 0.],
#  [0., 0., 1.],
#  [0., 1., 0.]]
# 따라서, 이 함수는 레이블 배열을 원-핫 인코딩 형식으로 변환하여 반환합니다.

# %%
# 데이터 로드
X_train = load_idx_file('train-images.idx3-ubyte')
y_train = load_idx_file('train-labels.idx1-ubyte')
X_test = load_idx_file('t10k-images.idx3-ubyte')
y_test = load_idx_file('t10k-labels.idx1-ubyte')

# %% [markdown]
# 이 코드는 MNIST 데이터셋의 훈련 이미지, 훈련 레이블, 테스트 이미지, 테스트 레이블을 파일에서 읽어오는 작업을 수행합니다. 각 줄을 해석해보겠습니다.
#
# python
# 코드 복사
# X_train = load_idx_file('train-images.idx3-ubyte')
# load_idx_file 함수를 호출하여 train-images.idx3-ubyte 파일에서 훈련 이미지를 읽어옵니다. 이 파일에는 훈련 이미지 데이터가 저장되어 있습니다.
# 반환된 데이터는 X_train 변수에 저장되며, 이 변수는 훈련 이미지의 픽셀 값들이 포함된 numpy 배열입니다.
# python
# 코드 복사
# y_train = load_idx_file('train-labels.idx1-ubyte')
# load_idx_file 함수를 호출하여 train-labels.idx1-ubyte 파일에서 훈련 레이블을 읽어옵니다. 이 파일에는 훈련 이미지에 대한 레이블이 저장되어 있습니다.
# 반환된 데이터는 y_train 변수에 저장되며, 이 변수는 훈련 이미지에 대한 레이블을 나타내는 정수 배열입니다.
# python
# 코드 복사
# X_test = load_idx_file('t10k-images.idx3-ubyte')
# load_idx_file 함수를 호출하여 t10k-images.idx3-ubyte 파일에서 테스트 이미지를 읽어옵니다. 이 파일에는 테스트 이미지 데이터가 저장되어 있습니다.
# 반환된 데이터는 X_test 변수에 저장되며, 이 변수는 테스트 이미지의 픽셀 값들이 포함된 numpy 배열입니다.
# python
# 코드 복사
# y_test = load_idx_file('t10k-labels.idx1-ubyte')
# load_idx_file 함수를 호출하여 t10k-labels.idx1-ubyte 파일에서 테스트 레이블을 읽어옵니다. 이 파일에는 테스트 이미지에 대한 레이블이 저장되어 있습니다.
# 반환된 데이터는 y_test 변수에 저장되며, 이 변수는 테스트 이미지에 대한 레이블을 나타내는 정수 배열입니다.

# %%
# 데이터 전처리
X_train = X_train / 255.0
X_test = X_test / 255.0
y_train_encoded = one_hot_encode(y_train, 10)
y_test_encoded = one_hot_encode(y_test, 10)

# %% [markdown]
# 이 코드는 MNIST 데이터셋의 전처리를 수행하여 모델 학습에 적합한 형식으로 변환합니다. 각 줄을 해석해보겠습니다.
#
# python
# 코드 복사
# X_train = X_train / 255.0
# X_train의 픽셀 값들을 255.0으로 나누어 [0, 1] 범위로 정규화(normalize)합니다. MNIST 이미지 데이터는 원래 0에서 255까지의 값을 가지므로, 이를 0과 1 사이의 값으로 변환하여 신경망의 학습을 안정화하고 수렴 속도를 향상시킵니다.
# python
# 코드 복사
# X_test = X_test / 255.0
# X_test의 픽셀 값들도 255.0으로 나누어 [0, 1] 범위로 정규화합니다. 훈련 데이터와 테스트 데이터 모두 동일한 전처리 과정을 거쳐야 모델의 일반화 성능이 향상됩니다.
# python
# 코드 복사
# y_train_encoded = one_hot_encode(y_train, 10)
# one_hot_encode 함수를 사용하여 y_train의 레이블을 원-핫 인코딩 형식으로 변환합니다. 10은 총 클래스의 개수를 의미하며, MNIST 데이터셋은 10개의 클래스(숫자 0부터 9까지)를 가지고 있습니다. 변환된 결과는 y_train_encoded 변수에 저장되며, 이 변수는 원-핫 인코딩된 훈련 레이블을 포함합니다.
# python
# 코드 복사
# y_test_encoded = one_hot_encode(y_test, 10)
# one_hot_encode 함수를 사용하여 y_test의 레이블을 원-핫 인코딩 형식으로 변환합니다. 10은 총 클래스의 개수를 의미하며, y_test_encoded 변수에 저장됩니다. 이 변수는 원-핫 인코딩된 테스트 레이블을 포함합니다.
# 이 전처리 과정은 이미지 데이터의 스케일을 조정하고 레이블을 원-핫 인코딩하여 신경망 모델이 데이터를 올바르게 처리할 수 있도록 합니다.

# %%
Mnist = Mnist_model(X_train,y_train_encoded,0.1,1000)
Mnist.Laerning()
# Out:
# Epoch 0, Loss: 2.3985
# Epoch 1, Loss: 2.2533
# Epoch 2, Loss: 2.1740
# Epoch 3, Loss: 2.1098
# Epoch 4, Loss: 2.0493
# Epoch 5, Loss: 1.9885
# Epoch 6, Loss: 1.9264
# Epoch 7, Loss: 1.8629
# Epoch 8, Loss: 1.7983
# Epoch 9, Loss: 1.7329
# Epoch 10, Loss: 1.6672
# Epoch 11, Loss: 1.6017
# Epoch 12, Loss: 1.5369
# Epoch 13, Loss: 1.4734
# Epoch 14, Loss: 1.4118
# Epoch 15, Loss: 1.3524
# Epoch 16, Loss: 1.2956
# Epoch 17, Loss: 1.2416
# Epoch 18, Loss: 1.1906
# Epoch 19, Loss: 1.1426
# Epoch 20, Loss: 1.0978
# Epoch 21, Loss: 1.0560
# Epoch 22, Loss: 1.0171
# Epoch 23, Loss: 0.9810
# Epoch 24, Loss: 0.9475
# Epoch 25, Loss: 0.9164
# Epoch 26, Loss: 0.8875
# Epoch 27, Loss: 0.8606
# Epoch 28, Loss: 0.8356
# Epoch 29, Loss: 0.8123
# Epoch 30, Loss: 0.7905
# Epoch 31, Loss: 0.7702
# Epoch 32, Loss: 0.7511
# Epoch 33, Loss: 0.7333
# Epoch 34, Loss: 0.7167
# Epoch 35, Loss: 0.7010
# Epoch 36, Loss: 0.6863
# Epoch 37, Loss: 0.6725
# Epoch 38, Loss: 0.6594
# Epoch 39, Loss: 0.6472
# Epoch 40, Loss: 0.6356
# Epoch 41, Loss: 0.6246
# Epoch 42, Loss: 0.6142
# Epoch 43, Loss: 0.6044
# Epoch 44, Loss: 0.5950
# Epoch 45, Loss: 0.5862
# Epoch 46, Loss: 0.5777
# Epoch 47, Loss: 0.5697
# Epoch 48, Loss: 0.5621
# Epoch 49, Loss: 0.5548
# Epoch 50, Loss: 0.5478
# Epoch 51, Loss: 0.5411
# Epoch 52, Loss: 0.5348
# Epoch 53, Loss: 0.5287
# Epoch 54, Loss: 0.5228
# Epoch 55, Loss: 0.5172
# Epoch 56, Loss: 0.5119
# Epoch 57, Loss: 0.5067
# Epoch 58, Loss: 0.5017
# Epoch 59, Loss: 0.4970
# Epoch 60, Loss: 0.4924
# Epoch 61, Loss: 0.4879
# Epoch 62, Loss: 0.4837
# Epoch 63, Loss: 0.4796
# Epoch 64, Loss: 0.4756
# Epoch 65, Loss: 0.4718
# Epoch 66, Loss: 0.4680
# Epoch 67, Loss: 0.4645
# Epoch 68, Loss: 0.4610
# Epoch 69, Loss: 0.4576
# Epoch 70, Loss: 0.4544
# Epoch 71, Loss: 0.4512
# Epoch 72, Loss: 0.4482
# Epoch 73, Loss: 0.4452
# Epoch 74, Loss: 0.4423
# Epoch 75, Loss: 0.4395
# Epoch 76, Loss: 0.4368
# Epoch 77, Loss: 0.4342
# Epoch 78, Loss: 0.4316
# Epoch 79, Loss: 0.4291
# Epoch 80, Loss: 0.4267
# Epoch 81, Loss: 0.4243
# Epoch 82, Loss: 0.4220
# Epoch 83, Loss: 0.4197
# Epoch 84, Loss: 0.4175
# Epoch 85, Loss: 0.4154
# Epoch 86, Loss: 0.4133
# Epoch 87, Loss: 0.4113
# Epoch 88, Loss: 0.4093
# Epoch 89, Loss: 0.4073
# Epoch 90, Loss: 0.4054
# Epoch 91, Loss: 0.4036
# Epoch 92, Loss: 0.4018
# Epoch 93, Loss: 0.4000
# Epoch 94, Loss: 0.3982
# Epoch 95, Loss: 0.3965
# Epoch 96, Loss: 0.3949
# Epoch 97, Loss: 0.3932
# Epoch 98, Loss: 0.3916
# Epoch 99, Loss: 0.3900
# Epoch 100, Loss: 0.3885
# Epoch 101, Loss: 0.3870
# Epoch 102, Loss: 0.3855
# Epoch 103, Loss: 0.3840
# Epoch 104, Loss: 0.3826
# Epoch 105, Loss: 0.3812
# Epoch 106, Loss: 0.3798
# Epoch 107, Loss: 0.3784
# Epoch 108, Loss: 0.3771
# Epoch 109, Loss: 0.3758
# Epoch 110, Loss: 0.3745
# Epoch 111, Loss: 0.3732
# Epoch 112, Loss: 0.3720
# Epoch 113, Loss: 0.3707
# Epoch 114, Loss: 0.3695
# Epoch 115, Loss: 0.3683
# Epoch 116, Loss: 0.3672
# Epoch 117, Loss: 0.3660
# Epoch 118, Loss: 0.3649
# Epoch 119, Loss: 0.3637
# Epoch 120, Loss: 0.3626
# Epoch 121, Loss: 0.3615
# Epoch 122, Loss: 0.3605
# Epoch 123, Loss: 0.3594
# Epoch 124, Loss: 0.3584
# Epoch 125, Loss: 0.3573
# Epoch 126, Loss: 0.3563
# Epoch 127, Loss: 0.3553
# Epoch 128, Loss: 0.3543
# Epoch 129, Loss: 0.3533
# Epoch 130, Loss: 0.3524
# Epoch 131, Loss: 0.3514
# Epoch 132, Loss: 0.3505
# Epoch 133, Loss: 0.3495
# Epoch 134, Loss: 0.3486
# Epoch 135, Loss: 0.3477
# Epoch 136, Loss: 0.3468
# Epoch 137, Loss: 0.3459
# Epoch 138, Loss: 0.3451
# Epoch 139, Loss: 0.3442
# Epoch 140, Loss: 0.3434
# Epoch 141, Loss: 0.3425
# Epoch 142, Loss: 0.3417
# Epoch 143, Loss: 0.3409
# Epoch 144, Loss: 0.3400
# Epoch 145, Loss: 0.3392
# Epoch 146, Loss: 0.3384
# Epoch 147, Loss: 0.3376
# Epoch 148, Loss: 0.3369
# Epoch 149, Loss: 0.3361
# Epoch 150, Loss: 0.3353
# Epoch 151, Loss: 0.3346
# Epoch 152, Loss: 0.3338
# Epoch 153, Loss: 0.3331
# Epoch 154, Loss: 0.3323
# Epoch 155, Loss: 0.3316
# Epoch 156, Loss: 0.3309
# Epoch 157, Loss: 0.3302
# Epoch 158, Loss: 0.3295
# Epoch 159, Loss: 0.3288
# Epoch 160, Loss: 0.3281
# Epoch 161, Loss: 0.3274
# Epoch 162, Loss: 0.3267
# Epoch 163, Loss: 0.3260
# Epoch 164, Loss: 0.3254
# Epoch 165, Loss: 0.3247
# Epoch 166, Loss: 0.3241
# Epoch 167, Loss: 0.3234
# Epoch 168, Loss: 0.3228
# Epoch 169, Loss: 0.3221
# Epoch 170, Loss: 0.3215
# Epoch 171, Loss: 0.3209
# Epoch 172, Loss: 0.3202
# Epoch 173, Loss: 0.3196
# Epoch 174, Loss: 0.3190
# Epoch 175, Loss: 0.3184
# Epoch 176, Loss: 0.3178
# Epoch 177, Loss: 0.3172
# Epoch 178, Loss: 0.3166
# Epoch 179, Loss: 0.3160
# Epoch 180, Loss: 0.3154
# Epoch 181, Loss: 0.3149
# Epoch 182, Loss: 0.3143
# Epoch 183, Loss: 0.3137
# Epoch 184, Loss: 0.3131
# Epoch 185, Loss: 0.3126
# Epoch 186, Loss: 0.3120
# Epoch 187, Loss: 0.3115
# Epoch 188, Loss: 0.3109
# Epoch 189, Loss: 0.3104
# Epoch 190, Loss: 0.3098
# Epoch 191, Loss: 0.3093
# Epoch 192, Loss: 0.3087
# Epoch 193, Loss: 0.3082
# Epoch 194, Loss: 0.3077
# Epoch 195, Loss: 0.3072
# Epoch 196, Loss: 0.3066
# Epoch 197, Loss: 0.3061
# Epoch 198, Loss: 0.3056
# Epoch 199, Loss: 0.3051
# Epoch 200, Loss: 0.3046
# Epoch 201, Loss: 0.3041
# Epoch 202, Loss: 0.3036
# Epoch 203, Loss: 0.3031
# Epoch 204, Loss: 0.3026
# Epoch 205, Loss: 0.3021
# Epoch 206, Loss: 0.3016
# Epoch 207, Loss: 0.3011
# Epoch 208, Loss: 0.3007
# Epoch 209, Loss: 0.3002
# Epoch 210, Loss: 0.2997
# Epoch 211, Loss: 0.2992
# Epoch 212, Loss: 0.2988
# Epoch 213, Loss: 0.2983
# Epoch 214, Loss: 0.2978
# Epoch 215, Loss: 0.2974
# Epoch 216, Loss: 0.2969
# Epoch 217, Loss: 0.2965
# Epoch 218, Loss: 0.2960
# Epoch 219, Loss: 0.2956
# Epoch 220, Loss: 0.2951
# Epoch 221, Loss: 0.2947
# Epoch 222, Loss: 0.2942
# Epoch 223, Loss: 0.2938
# Epoch 224, Loss: 0.2933
# Epoch 225, Loss: 0.2929
# Epoch 226, Loss: 0.2925
# Epoch 227, Loss: 0.2920
# Epoch 228, Loss: 0.2916
# Epoch 229, Loss: 0.2912
# Epoch 230, Loss: 0.2907
# Epoch 231, Loss: 0.2903
# Epoch 232, Loss: 0.2899
# Epoch 233, Loss: 0.2895
# Epoch 234, Loss: 0.2891
# Epoch 235, Loss: 0.2886
# Epoch 236, Loss: 0.2882
# Epoch 237, Loss: 0.2878
# Epoch 238, Loss: 0.2874
# Epoch 239, Loss: 0.2870
# Epoch 240, Loss: 0.2866
# Epoch 241, Loss: 0.2862
# Epoch 242, Loss: 0.2858
# Epoch 243, Loss: 0.2854
# Epoch 244, Loss: 0.2850
# Epoch 245, Loss: 0.2846
# Epoch 246, Loss: 0.2842
# Epoch 247, Loss: 0.2838
# Epoch 248, Loss: 0.2834
# Epoch 249, Loss: 0.2830
# Epoch 250, Loss: 0.2826
# Epoch 251, Loss: 0.2823
# Epoch 252, Loss: 0.2819
# Epoch 253, Loss: 0.2815
# Epoch 254, Loss: 0.2811
# Epoch 255, Loss: 0.2807
# Epoch 256, Loss: 0.2804
# Epoch 257, Loss: 0.2800
# Epoch 258, Loss: 0.2796
# Epoch 259, Loss: 0.2792
# Epoch 260, Loss: 0.2789
# Epoch 261, Loss: 0.2785
# Epoch 262, Loss: 0.2781
# Epoch 263, Loss: 0.2778
# Epoch 264, Loss: 0.2774
# Epoch 265, Loss: 0.2770
# Epoch 266, Loss: 0.2767
# Epoch 267, Loss: 0.2763
# Epoch 268, Loss: 0.2760
# Epoch 269, Loss: 0.2756
# Epoch 270, Loss: 0.2752
# Epoch 271, Loss: 0.2749
# Epoch 272, Loss: 0.2745
# Epoch 273, Loss: 0.2742
# Epoch 274, Loss: 0.2738
# Epoch 275, Loss: 0.2735
# Epoch 276, Loss: 0.2731
# Epoch 277, Loss: 0.2728
# Epoch 278, Loss: 0.2725
# Epoch 279, Loss: 0.2721
# Epoch 280, Loss: 0.2718
# Epoch 281, Loss: 0.2714
# Epoch 282, Loss: 0.2711
# Epoch 283, Loss: 0.2708
# Epoch 284, Loss: 0.2704
# Epoch 285, Loss: 0.2701
# Epoch 286, Loss: 0.2698
# Epoch 287, Loss: 0.2694
# Epoch 288, Loss: 0.2691
# Epoch 289, Loss: 0.2688
# Epoch 290, Loss: 0.2684
# Epoch 291, Loss: 0.2681
# Epoch 292, Loss: 0.2678
# Epoch 293, Loss: 0.2675
# Epoch 294, Loss: 0.2671
# Epoch 295, Loss: 0.2668
# Epoch 296, Loss: 0.2665
# Epoch 297, Loss: 0.2662
# Epoch 298, Loss: 0.2659
# Epoch 299, Loss: 0.2656
# Epoch 300, Loss: 0.2652
# Epoch 301, Loss: 0.2649
# Epoch 302, Loss: 0.2646
# Epoch 303, Loss: 0.2643
# Epoch 304, Loss: 0.2640
# Epoch 305, Loss: 0.2637
# Epoch 306, Loss: 0.2634
# Epoch 307, Loss: 0.2631
# Epoch 308, Loss: 0.2628
# Epoch 309, Loss: 0.2625
# Epoch 310, Loss: 0.2622
# Epoch 311, Loss: 0.2619
# Epoch 312, Loss: 0.2616
# Epoch 313, Loss: 0.2612
# Epoch 314, Loss: 0.2610
# Epoch 315, Loss: 0.2607
# Epoch 316, Loss: 0.2604
# Epoch 317, Loss: 0.2601
# Epoch 318, Loss: 0.2598
# Epoch 319, Loss: 0.2595
# Epoch 320, Loss: 0.2592
# Epoch 321, Loss: 0.2589
# Epoch 322, Loss: 0.2586
# Epoch 323, Loss: 0.2583
# Epoch 324, Loss: 0.2580
# Epoch 325, Loss: 0.2577
# Epoch 326, Loss: 0.2574
# Epoch 327, Loss: 0.2571
# Epoch 328, Loss: 0.2569
# Epoch 329, Loss: 0.2566
# Epoch 330, Loss: 0.2563
# Epoch 331, Loss: 0.2560
# Epoch 332, Loss: 0.2557
# Epoch 333, Loss: 0.2554
# Epoch 334, Loss: 0.2552
# Epoch 335, Loss: 0.2549
# Epoch 336, Loss: 0.2546
# Epoch 337, Loss: 0.2543
# Epoch 338, Loss: 0.2540
# Epoch 339, Loss: 0.2538
# Epoch 340, Loss: 0.2535
# Epoch 341, Loss: 0.2532
# Epoch 342, Loss: 0.2529
# Epoch 343, Loss: 0.2527
# Epoch 344, Loss: 0.2524
# Epoch 345, Loss: 0.2521
# Epoch 346, Loss: 0.2518
# Epoch 347, Loss: 0.2516
# Epoch 348, Loss: 0.2513
# Epoch 349, Loss: 0.2510
# Epoch 350, Loss: 0.2508
# Epoch 351, Loss: 0.2505
# Epoch 352, Loss: 0.2502
# Epoch 353, Loss: 0.2500
# Epoch 354, Loss: 0.2497
# Epoch 355, Loss: 0.2494
# Epoch 356, Loss: 0.2492
# Epoch 357, Loss: 0.2489
# Epoch 358, Loss: 0.2486
# Epoch 359, Loss: 0.2484
# Epoch 360, Loss: 0.2481
# Epoch 361, Loss: 0.2478
# Epoch 362, Loss: 0.2476
# Epoch 363, Loss: 0.2473
# Epoch 364, Loss: 0.2471
# Epoch 365, Loss: 0.2468
# Epoch 366, Loss: 0.2465
# Epoch 367, Loss: 0.2463
# Epoch 368, Loss: 0.2460
# Epoch 369, Loss: 0.2458
# Epoch 370, Loss: 0.2455
# Epoch 371, Loss: 0.2453
# Epoch 372, Loss: 0.2450
# Epoch 373, Loss: 0.2448
# Epoch 374, Loss: 0.2445
# Epoch 375, Loss: 0.2443
# Epoch 376, Loss: 0.2440
# Epoch 377, Loss: 0.2438
# Epoch 378, Loss: 0.2435
# Epoch 379, Loss: 0.2433
# Epoch 380, Loss: 0.2430
# Epoch 381, Loss: 0.2428
# Epoch 382, Loss: 0.2425
# Epoch 383, Loss: 0.2423
# Epoch 384, Loss: 0.2420
# Epoch 385, Loss: 0.2418
# Epoch 386, Loss: 0.2415
# Epoch 387, Loss: 0.2413
# Epoch 388, Loss: 0.2410
# Epoch 389, Loss: 0.2408
# Epoch 390, Loss: 0.2405
# Epoch 391, Loss: 0.2403
# Epoch 392, Loss: 0.2401
# Epoch 393, Loss: 0.2398
# Epoch 394, Loss: 0.2396
# Epoch 395, Loss: 0.2393
# Epoch 396, Loss: 0.2391
# Epoch 397, Loss: 0.2389
# Epoch 398, Loss: 0.2386
# Epoch 399, Loss: 0.2384
# Epoch 400, Loss: 0.2381
# Epoch 401, Loss: 0.2379
# Epoch 402, Loss: 0.2377
# Epoch 403, Loss: 0.2374
# Epoch 404, Loss: 0.2372
# Epoch 405, Loss: 0.2370
# Epoch 406, Loss: 0.2367
# Epoch 407, Loss: 0.2365
# Epoch 408, Loss: 0.2363
# Epoch 409, Loss: 0.2360
# Epoch 410, Loss: 0.2358
# Epoch 411, Loss: 0.2356
# Epoch 412, Loss: 0.2354
# Epoch 413, Loss: 0.2351
# Epoch 414, Loss: 0.2349
# Epoch 415, Loss: 0.2347
# Epoch 416, Loss: 0.2344
# Epoch 417, Loss: 0.2342
# Epoch 418, Loss: 0.2340
# Epoch 419, Loss: 0.2338
# Epoch 420, Loss: 0.2335
# Epoch 421, Loss: 0.2333
# Epoch 422, Loss: 0.2331
# Epoch 423, Loss: 0.2329
# Epoch 424, Loss: 0.2326
# Epoch 425, Loss: 0.2324
# Epoch 426, Loss: 0.2322
# Epoch 427, Loss: 0.2320
# Epoch 428, Loss: 0.2317
# Epoch 429, Loss: 0.2315
# Epoch 430, Loss: 0.2313
# Epoch 431, Loss: 0.2311
# Epoch 432, Loss: 0.2309
# Epoch 433, Loss: 0.2306
# Epoch 434, Loss: 0.2304
# Epoch 435, Loss: 0.2302
# Epoch 436, Loss: 0.2300
# Epoch 437, Loss: 0.2298
# Epoch 438, Loss: 0.2296
# Epoch 439, Loss: 0.2293
# Epoch 440, Loss: 0.2291
# Epoch 441, Loss: 0.2289
# Epoch 442, Loss: 0.2287
# Epoch 443, Loss: 0.2285
# Epoch 444, Loss: 0.2283
# Epoch 445, Loss: 0.2281
# Epoch 446, Loss: 0.2278
# Epoch 447, Loss: 0.2276
# Epoch 448, Loss: 0.2274
# Epoch 449, Loss: 0.2272
# Epoch 450, Loss: 0.2270
# Epoch 451, Loss: 0.2268
# Epoch 452, Loss: 0.2266
# Epoch 453, Loss: 0.2264
# Epoch 454, Loss: 0.2262
# Epoch 455, Loss: 0.2260
# Epoch 456, Loss: 0.2257
# Epoch 457, Loss: 0.2255
# Epoch 458, Loss: 0.2253
# Epoch 459, Loss: 0.2251
# Epoch 460, Loss: 0.2249
# Epoch 461, Loss: 0.2247
# Epoch 462, Loss: 0.2245
# Epoch 463, Loss: 0.2243
# Epoch 464, Loss: 0.2241
# Epoch 465, Loss: 0.2239
# Epoch 466, Loss: 0.2237
# Epoch 467, Loss: 0.2235
# Epoch 468, Loss: 0.2233
# Epoch 469, Loss: 0.2231
# Epoch 470, Loss: 0.2229
# Epoch 471, Loss: 0.2227
# Epoch 472, Loss: 0.2225
# Epoch 473, Loss: 0.2223
# Epoch 474, Loss: 0.2221
# Epoch 475, Loss: 0.2219
# Epoch 476, Loss: 0.2217
# Epoch 477, Loss: 0.2215
# Epoch 478, Loss: 0.2213
# Epoch 479, Loss: 0.2211
# Epoch 480, Loss: 0.2209
# Epoch 481, Loss: 0.2207
# Epoch 482, Loss: 0.2205
# Epoch 483, Loss: 0.2203
# Epoch 484, Loss: 0.2201
# Epoch 485, Loss: 0.2199
# Epoch 486, Loss: 0.2197
# Epoch 487, Loss: 0.2195
# Epoch 488, Loss: 0.2193
# Epoch 489, Loss: 0.2191
# Epoch 490, Loss: 0.2189
# Epoch 491, Loss: 0.2187
# Epoch 492, Loss: 0.2185
# Epoch 493, Loss: 0.2183
# Epoch 494, Loss: 0.2181
# Epoch 495, Loss: 0.2180
# Epoch 496, Loss: 0.2178
# Epoch 497, Loss: 0.2176
# Epoch 498, Loss: 0.2174
# Epoch 499, Loss: 0.2172
# Epoch 500, Loss: 0.2170
# Epoch 501, Loss: 0.2168
# Epoch 502, Loss: 0.2166
# Epoch 503, Loss: 0.2164
# Epoch 504, Loss: 0.2162
# Epoch 505, Loss: 0.2161
# Epoch 506, Loss: 0.2159
# Epoch 507, Loss: 0.2157
# Epoch 508, Loss: 0.2155
# Epoch 509, Loss: 0.2153
# Epoch 510, Loss: 0.2151
# Epoch 511, Loss: 0.2149
# Epoch 512, Loss: 0.2148
# Epoch 513, Loss: 0.2146
# Epoch 514, Loss: 0.2144
# Epoch 515, Loss: 0.2142
# Epoch 516, Loss: 0.2140
# Epoch 517, Loss: 0.2138
# Epoch 518, Loss: 0.2136
# Epoch 519, Loss: 0.2135
# Epoch 520, Loss: 0.2133
# Epoch 521, Loss: 0.2131
# Epoch 522, Loss: 0.2129
# Epoch 523, Loss: 0.2127
# Epoch 524, Loss: 0.2126
# Epoch 525, Loss: 0.2124
# Epoch 526, Loss: 0.2122
# Epoch 527, Loss: 0.2120
# Epoch 528, Loss: 0.2118
# Epoch 529, Loss: 0.2117
# Epoch 530, Loss: 0.2115
# Epoch 531, Loss: 0.2113
# Epoch 532, Loss: 0.2111
# Epoch 533, Loss: 0.2110
# Epoch 534, Loss: 0.2108
# Epoch 535, Loss: 0.2106
# Epoch 536, Loss: 0.2104
# Epoch 537, Loss: 0.2102
# Epoch 538, Loss: 0.2101
# Epoch 539, Loss: 0.2099
# Epoch 540, Loss: 0.2097
# Epoch 541, Loss: 0.2095
# Epoch 542, Loss: 0.2094
# Epoch 543, Loss: 0.2092
# Epoch 544, Loss: 0.2090
# Epoch 545, Loss: 0.2089
# Epoch 546, Loss: 0.2087
# Epoch 547, Loss: 0.2085
# Epoch 548, Loss: 0.2083
# Epoch 549, Loss: 0.2082
# Epoch 550, Loss: 0.2080
# Epoch 551, Loss: 0.2078
# Epoch 552, Loss: 0.2076
# Epoch 553, Loss: 0.2075
# Epoch 554, Loss: 0.2073
# Epoch 555, Loss: 0.2071
# Epoch 556, Loss: 0.2070
# Epoch 557, Loss: 0.2068
# Epoch 558, Loss: 0.2066
# Epoch 559, Loss: 0.2065
# Epoch 560, Loss: 0.2063
# Epoch 561, Loss: 0.2061
# Epoch 562, Loss: 0.2060
# Epoch 563, Loss: 0.2058
# Epoch 564, Loss: 0.2056
# Epoch 565, Loss: 0.2055
# Epoch 566, Loss: 0.2053
# Epoch 567, Loss: 0.2051
# Epoch 568, Loss: 0.2050
# Epoch 569, Loss: 0.2048
# Epoch 570, Loss: 0.2046
# Epoch 571, Loss: 0.2045
# Epoch 572, Loss: 0.2043
# Epoch 573, Loss: 0.2041
# Epoch 574, Loss: 0.2040
# Epoch 575, Loss: 0.2038
# Epoch 576, Loss: 0.2037
# Epoch 577, Loss: 0.2035
# Epoch 578, Loss: 0.2033
# Epoch 579, Loss: 0.2032
# Epoch 580, Loss: 0.2030
# Epoch 581, Loss: 0.2028
# Epoch 582, Loss: 0.2027
# Epoch 583, Loss: 0.2025
# Epoch 584, Loss: 0.2024
# Epoch 585, Loss: 0.2022
# Epoch 586, Loss: 0.2020
# Epoch 587, Loss: 0.2019
# Epoch 588, Loss: 0.2017
# Epoch 589, Loss: 0.2016
# Epoch 590, Loss: 0.2014
# Epoch 591, Loss: 0.2012
# Epoch 592, Loss: 0.2011
# Epoch 593, Loss: 0.2009
# Epoch 594, Loss: 0.2008
# Epoch 595, Loss: 0.2006
# Epoch 596, Loss: 0.2005
# Epoch 597, Loss: 0.2003
# Epoch 598, Loss: 0.2001
# Epoch 599, Loss: 0.2000
# Epoch 600, Loss: 0.1998
# Epoch 601, Loss: 0.1997
# Epoch 602, Loss: 0.1995
# Epoch 603, Loss: 0.1994
# Epoch 604, Loss: 0.1992
# Epoch 605, Loss: 0.1991
# Epoch 606, Loss: 0.1989
# Epoch 607, Loss: 0.1988
# Epoch 608, Loss: 0.1986
# Epoch 609, Loss: 0.1985
# Epoch 610, Loss: 0.1983
# Epoch 611, Loss: 0.1981
# Epoch 612, Loss: 0.1980
# Epoch 613, Loss: 0.1978
# Epoch 614, Loss: 0.1977
# Epoch 615, Loss: 0.1975
# Epoch 616, Loss: 0.1974
# Epoch 617, Loss: 0.1972
# Epoch 618, Loss: 0.1971
# Epoch 619, Loss: 0.1969
# Epoch 620, Loss: 0.1968
# Epoch 621, Loss: 0.1966
# Epoch 622, Loss: 0.1965
# Epoch 623, Loss: 0.1963
# Epoch 624, Loss: 0.1962
# Epoch 625, Loss: 0.1961
# Epoch 626, Loss: 0.1959
# Epoch 627, Loss: 0.1958
# Epoch 628, Loss: 0.1956
# Epoch 629, Loss: 0.1955
# Epoch 630, Loss: 0.1953
# Epoch 631, Loss: 0.1952
# Epoch 632, Loss: 0.1950
# Epoch 633, Loss: 0.1949
# Epoch 634, Loss: 0.1947
# Epoch 635, Loss: 0.1946
# Epoch 636, Loss: 0.1944
# Epoch 637, Loss: 0.1943
# Epoch 638, Loss: 0.1942
# Epoch 639, Loss: 0.1940
# Epoch 640, Loss: 0.1939
# Epoch 641, Loss: 0.1937
# Epoch 642, Loss: 0.1936
# Epoch 643, Loss: 0.1934
# Epoch 644, Loss: 0.1933
# Epoch 645, Loss: 0.1932
# Epoch 646, Loss: 0.1930
# Epoch 647, Loss: 0.1929
# Epoch 648, Loss: 0.1927
# Epoch 649, Loss: 0.1926
# Epoch 650, Loss: 0.1925
# Epoch 651, Loss: 0.1923
# Epoch 652, Loss: 0.1922
# Epoch 653, Loss: 0.1920
# Epoch 654, Loss: 0.1919
# Epoch 655, Loss: 0.1918
# Epoch 656, Loss: 0.1916
# Epoch 657, Loss: 0.1915
# Epoch 658, Loss: 0.1913
# Epoch 659, Loss: 0.1912
# Epoch 660, Loss: 0.1911
# Epoch 661, Loss: 0.1909
# Epoch 662, Loss: 0.1908
# Epoch 663, Loss: 0.1906
# Epoch 664, Loss: 0.1905
# Epoch 665, Loss: 0.1904
# Epoch 666, Loss: 0.1902
# Epoch 667, Loss: 0.1901
# Epoch 668, Loss: 0.1900
# Epoch 669, Loss: 0.1898
# Epoch 670, Loss: 0.1897
# Epoch 671, Loss: 0.1896
# Epoch 672, Loss: 0.1894
# Epoch 673, Loss: 0.1893
# Epoch 674, Loss: 0.1892
# Epoch 675, Loss: 0.1890
# Epoch 676, Loss: 0.1889
# Epoch 677, Loss: 0.1887
# Epoch 678, Loss: 0.1886
# Epoch 679, Loss: 0.1885
# Epoch 680, Loss: 0.1883
# Epoch 681, Loss: 0.1882
# Epoch 682, Loss: 0.1881
# Epoch 683, Loss: 0.1879
# Epoch 684, Loss: 0.1878
# Epoch 685, Loss: 0.1877
# Epoch 686, Loss: 0.1876
# Epoch 687, Loss: 0.1874
# Epoch 688, Loss: 0.1873
# Epoch 689, Loss: 0.1872
# Epoch 690, Loss: 0.1870
# Epoch 691, Loss: 0.1869
# Epoch 692, Loss: 0.1868
# Epoch 693, Loss: 0.1866
# Epoch 694, Loss: 0.1865
# Epoch 695, Loss: 0.1864
# Epoch 696, Loss: 0.1862
# Epoch 697, Loss: 0.1861
# Epoch 698, Loss: 0.1860
# Epoch 699, Loss: 0.1859
# Epoch 700, Loss: 0.1857
# Epoch 701, Loss: 0.1856
# Epoch 702, Loss: 0.1855
# Epoch 703, Loss: 0.1853
# Epoch 704, Loss: 0.1852
# Epoch 705, Loss: 0.1851
# Epoch 706, Loss: 0.1850
# Epoch 707, Loss: 0.1848
# Epoch 708, Loss: 0.1847
# Epoch 709, Loss: 0.1846
# Epoch 710, Loss: 0.1844
# Epoch 711, Loss: 0.1843
# Epoch 712, Loss: 0.1842
# Epoch 713, Loss: 0.1841
# Epoch 714, Loss: 0.1839
# Epoch 715, Loss: 0.1838
# Epoch 716, Loss: 0.1837
# Epoch 717, Loss: 0.1836
# Epoch 718, Loss: 0.1834
# Epoch 719, Loss: 0.1833
# Epoch 720, Loss: 0.1832
# Epoch 721, Loss: 0.1831
# Epoch 722, Loss: 0.1829
# Epoch 723, Loss: 0.1828
# Epoch 724, Loss: 0.1827
# Epoch 725, Loss: 0.1826
# Epoch 726, Loss: 0.1824
# Epoch 727, Loss: 0.1823
# Epoch 728, Loss: 0.1822
# Epoch 729, Loss: 0.1821
# Epoch 730, Loss: 0.1819
# Epoch 731, Loss: 0.1818
# Epoch 732, Loss: 0.1817
# Epoch 733, Loss: 0.1816
# Epoch 734, Loss: 0.1815
# Epoch 735, Loss: 0.1813
# Epoch 736, Loss: 0.1812
# Epoch 737, Loss: 0.1811
# Epoch 738, Loss: 0.1810
# Epoch 739, Loss: 0.1809
# Epoch 740, Loss: 0.1807
# Epoch 741, Loss: 0.1806
# Epoch 742, Loss: 0.1805
# Epoch 743, Loss: 0.1804
# Epoch 744, Loss: 0.1802
# Epoch 745, Loss: 0.1801
# Epoch 746, Loss: 0.1800
# Epoch 747, Loss: 0.1799
# Epoch 748, Loss: 0.1798
# Epoch 749, Loss: 0.1796
# Epoch 750, Loss: 0.1795
# Epoch 751, Loss: 0.1794
# Epoch 752, Loss: 0.1793
# Epoch 753, Loss: 0.1792
# Epoch 754, Loss: 0.1791
# Epoch 755, Loss: 0.1789
# Epoch 756, Loss: 0.1788
# Epoch 757, Loss: 0.1787
# Epoch 758, Loss: 0.1786
# Epoch 759, Loss: 0.1785
# Epoch 760, Loss: 0.1783
# Epoch 761, Loss: 0.1782
# Epoch 762, Loss: 0.1781
# Epoch 763, Loss: 0.1780
# Epoch 764, Loss: 0.1779
# Epoch 765, Loss: 0.1778
# Epoch 766, Loss: 0.1776
# Epoch 767, Loss: 0.1775
# Epoch 768, Loss: 0.1774
# Epoch 769, Loss: 0.1773
# Epoch 770, Loss: 0.1772
# Epoch 771, Loss: 0.1771
# Epoch 772, Loss: 0.1769
# Epoch 773, Loss: 0.1768
# Epoch 774, Loss: 0.1767
# Epoch 775, Loss: 0.1766
# Epoch 776, Loss: 0.1765
# Epoch 777, Loss: 0.1764
# Epoch 778, Loss: 0.1763
# Epoch 779, Loss: 0.1761
# Epoch 780, Loss: 0.1760
# Epoch 781, Loss: 0.1759
# Epoch 782, Loss: 0.1758
# Epoch 783, Loss: 0.1757
# Epoch 784, Loss: 0.1756
# Epoch 785, Loss: 0.1755
# Epoch 786, Loss: 0.1754
# Epoch 787, Loss: 0.1752
# Epoch 788, Loss: 0.1751
# Epoch 789, Loss: 0.1750
# Epoch 790, Loss: 0.1749
# Epoch 791, Loss: 0.1748
# Epoch 792, Loss: 0.1747
# Epoch 793, Loss: 0.1746
# Epoch 794, Loss: 0.1744
# Epoch 795, Loss: 0.1743
# Epoch 796, Loss: 0.1742
# Epoch 797, Loss: 0.1741
# Epoch 798, Loss: 0.1740
# Epoch 799, Loss: 0.1739
# Epoch 800, Loss: 0.1738
# Epoch 801, Loss: 0.1737
# Epoch 802, Loss: 0.1736
# Epoch 803, Loss: 0.1734
# Epoch 804, Loss: 0.1733
# Epoch 805, Loss: 0.1732
# Epoch 806, Loss: 0.1731
# Epoch 807, Loss: 0.1730
# Epoch 808, Loss: 0.1729
# Epoch 809, Loss: 0.1728
# Epoch 810, Loss: 0.1727
# Epoch 811, Loss: 0.1726
# Epoch 812, Loss: 0.1725
# Epoch 813, Loss: 0.1723
# Epoch 814, Loss: 0.1722
# Epoch 815, Loss: 0.1721
# Epoch 816, Loss: 0.1720
# Epoch 817, Loss: 0.1719
# Epoch 818, Loss: 0.1718
# Epoch 819, Loss: 0.1717
# Epoch 820, Loss: 0.1716
# Epoch 821, Loss: 0.1715
# Epoch 822, Loss: 0.1714
# Epoch 823, Loss: 0.1713
# Epoch 824, Loss: 0.1712
# Epoch 825, Loss: 0.1710
# Epoch 826, Loss: 0.1709
# Epoch 827, Loss: 0.1708
# Epoch 828, Loss: 0.1707
# Epoch 829, Loss: 0.1706
# Epoch 830, Loss: 0.1705
# Epoch 831, Loss: 0.1704
# Epoch 832, Loss: 0.1703
# Epoch 833, Loss: 0.1702
# Epoch 834, Loss: 0.1701
# Epoch 835, Loss: 0.1700
# Epoch 836, Loss: 0.1699
# Epoch 837, Loss: 0.1698
# Epoch 838, Loss: 0.1697
# Epoch 839, Loss: 0.1696
# Epoch 840, Loss: 0.1695
# Epoch 841, Loss: 0.1694
# Epoch 842, Loss: 0.1693
# Epoch 843, Loss: 0.1691
# Epoch 844, Loss: 0.1690
# Epoch 845, Loss: 0.1689
# Epoch 846, Loss: 0.1688
# Epoch 847, Loss: 0.1687
# Epoch 848, Loss: 0.1686
# Epoch 849, Loss: 0.1685
# Epoch 850, Loss: 0.1684
# Epoch 851, Loss: 0.1683
# Epoch 852, Loss: 0.1682
# Epoch 853, Loss: 0.1681
# Epoch 854, Loss: 0.1680
# Epoch 855, Loss: 0.1679
# Epoch 856, Loss: 0.1678
# Epoch 857, Loss: 0.1677
# Epoch 858, Loss: 0.1676
# Epoch 859, Loss: 0.1675
# Epoch 860, Loss: 0.1674
# Epoch 861, Loss: 0.1673
# Epoch 862, Loss: 0.1672
# Epoch 863, Loss: 0.1671
# Epoch 864, Loss: 0.1670
# Epoch 865, Loss: 0.1669
# Epoch 866, Loss: 0.1668
# Epoch 867, Loss: 0.1667
# Epoch 868, Loss: 0.1666
# Epoch 869, Loss: 0.1665
# Epoch 870, Loss: 0.1664
# Epoch 871, Loss: 0.1663
# Epoch 872, Loss: 0.1662
# Epoch 873, Loss: 0.1661
# Epoch 874, Loss: 0.1660
# Epoch 875, Loss: 0.1659
# Epoch 876, Loss: 0.1658
# Epoch 877, Loss: 0.1657
# Epoch 878, Loss: 0.1656
# Epoch 879, Loss: 0.1655
# Epoch 880, Loss: 0.1654
# Epoch 881, Loss: 0.1653
# Epoch 882, Loss: 0.1652
# Epoch 883, Loss: 0.1651
# Epoch 884, Loss: 0.1650
# Epoch 885, Loss: 0.1649
# Epoch 886, Loss: 0.1648
# Epoch 887, Loss: 0.1647
# Epoch 888, Loss: 0.1646
# Epoch 889, Loss: 0.1645
# Epoch 890, Loss: 0.1644
# Epoch 891, Loss: 0.1643
# Epoch 892, Loss: 0.1642
# Epoch 893, Loss: 0.1641
# Epoch 894, Loss: 0.1640
# Epoch 895, Loss: 0.1639
# Epoch 896, Loss: 0.1638
# Epoch 897, Loss: 0.1637
# Epoch 898, Loss: 0.1636
# Epoch 899, Loss: 0.1635
# Epoch 900, Loss: 0.1635
# Epoch 901, Loss: 0.1634
# Epoch 902, Loss: 0.1633
# Epoch 903, Loss: 0.1632
# Epoch 904, Loss: 0.1631
# Epoch 905, Loss: 0.1630
# Epoch 906, Loss: 0.1629
# Epoch 907, Loss: 0.1628
# Epoch 908, Loss: 0.1627
# Epoch 909, Loss: 0.1626
# Epoch 910, Loss: 0.1625
# Epoch 911, Loss: 0.1624
# Epoch 912, Loss: 0.1623
# Epoch 913, Loss: 0.1622
# Epoch 914, Loss: 0.1621
# Epoch 915, Loss: 0.1620
# Epoch 916, Loss: 0.1619
# Epoch 917, Loss: 0.1618
# Epoch 918, Loss: 0.1617
# Epoch 919, Loss: 0.1617
# Epoch 920, Loss: 0.1616
# Epoch 921, Loss: 0.1615
# Epoch 922, Loss: 0.1614
# Epoch 923, Loss: 0.1613
# Epoch 924, Loss: 0.1612
# Epoch 925, Loss: 0.1611
# Epoch 926, Loss: 0.1610
# Epoch 927, Loss: 0.1609
# Epoch 928, Loss: 0.1608
# Epoch 929, Loss: 0.1607
# Epoch 930, Loss: 0.1606
# Epoch 931, Loss: 0.1605
# Epoch 932, Loss: 0.1605
# Epoch 933, Loss: 0.1604
# Epoch 934, Loss: 0.1603
# Epoch 935, Loss: 0.1602
# Epoch 936, Loss: 0.1601
# Epoch 937, Loss: 0.1600
# Epoch 938, Loss: 0.1599
# Epoch 939, Loss: 0.1598
# Epoch 940, Loss: 0.1597
# Epoch 941, Loss: 0.1596
# Epoch 942, Loss: 0.1595
# Epoch 943, Loss: 0.1595
# Epoch 944, Loss: 0.1594
# Epoch 945, Loss: 0.1593
# Epoch 946, Loss: 0.1592
# Epoch 947, Loss: 0.1591
# Epoch 948, Loss: 0.1590
# Epoch 949, Loss: 0.1589
# Epoch 950, Loss: 0.1588
# Epoch 951, Loss: 0.1587
# Epoch 952, Loss: 0.1586
# Epoch 953, Loss: 0.1586
# Epoch 954, Loss: 0.1585
# Epoch 955, Loss: 0.1584
# Epoch 956, Loss: 0.1583
# Epoch 957, Loss: 0.1582
# Epoch 958, Loss: 0.1581
# Epoch 959, Loss: 0.1580
# Epoch 960, Loss: 0.1579
# Epoch 961, Loss: 0.1579
# Epoch 962, Loss: 0.1578
# Epoch 963, Loss: 0.1577
# Epoch 964, Loss: 0.1576
# Epoch 965, Loss: 0.1575
# Epoch 966, Loss: 0.1574
# Epoch 967, Loss: 0.1573
# Epoch 968, Loss: 0.1572
# Epoch 969, Loss: 0.1572
# Epoch 970, Loss: 0.1571
# Epoch 971, Loss: 0.1570
# Epoch 972, Loss: 0.1569
# Epoch 973, Loss: 0.1568
# Epoch 974, Loss: 0.1567
# Epoch 975, Loss: 0.1566
# Epoch 976, Loss: 0.1565
# Epoch 977, Loss: 0.1565
# Epoch 978, Loss: 0.1564
# Epoch 979, Loss: 0.1563
# Epoch 980, Loss: 0.1562
# Epoch 981, Loss: 0.1561
# Epoch 982, Loss: 0.1560
# Epoch 983, Loss: 0.1559
# Epoch 984, Loss: 0.1559
# Epoch 985, Loss: 0.1558
# Epoch 986, Loss: 0.1557
# Epoch 987, Loss: 0.1556
# Epoch 988, Loss: 0.1555
# Epoch 989, Loss: 0.1554
# Epoch 990, Loss: 0.1554
# Epoch 991, Loss: 0.1553
# Epoch 992, Loss: 0.1552
# Epoch 993, Loss: 0.1551
# Epoch 994, Loss: 0.1550
# Epoch 995, Loss: 0.1549
# Epoch 996, Loss: 0.1548
# Epoch 997, Loss: 0.1548
# Epoch 998, Loss: 0.1547
# Epoch 999, Loss: 0.1546
# Train Accuracy: 0.9566, Test Accuracy: 0.9535

# %% [markdown]
# 이 코드는 Mnist_model 클래스를 사용하여 MNIST 데이터셋으로 모델을 훈련시키는 과정입니다. 한 줄씩 해석해보겠습니다.
#
# python
# 코드 복사
# Mnist = Mnist_model(X_train, y_train_encoded, 0.1, 1000)
# Mnist_model 클래스의 인스턴스를 생성합니다.
# X_train은 훈련 이미지 데이터, y_train_encoded는 원-핫 인코딩된 훈련 레이블, 0.1은 학습률(learning rate), 1000은 에폭 수(epoch)를 의미합니다.
# Mnist 변수에 Mnist_model 클래스의 인스턴스를 저장합니다. 이 인스턴스는 훈련 데이터와 하이퍼파라미터를 사용하여 모델을 초기화합니다.
# python
# 코드 복사
# Mnist.Laerning()
# Mnist 인스턴스의 Laerning 메서드를 호출하여 모델을 훈련시킵니다. (Laerning은 아마도 Learning의 오타일 것입니다.)
# 이 메서드는 지정된 에폭 수만큼 데이터에 대해 순전파와 역전파를 수행하며, 가중치와 바이어스를 업데이트하고 매 에폭마다 손실 값을 출력합니다.
# 이 코드의 목적은 MNIST 데이터셋을 사용하여 Mnist_model 인스턴스를 학습시키는 것입니다.

# %%
train_accuracy = Mnist.evaluate(X_train,y_train_encoded)
test_accuracy = Mnist.evaluate(X_test,y_test_encoded)
print(f"Train Accuracy: {train_accuracy:.4f}, Test Accuracy: {test_accuracy:.4f}")
# Out:
# Train Accuracy: 0.9566, Test Accuracy: 0.9535

# %% [markdown]
# 이 코드는 훈련 데이터와 테스트 데이터에 대해 모델의 정확도를 평가하고, 그 결과를 출력합니다. 각 줄을 해석해보겠습니다.
#
# python
# 코드 복사
# train_accuracy = Mnist.evaluate(X_train, y_train_encoded)
# Mnist 인스턴스의 evaluate 메서드를 호출하여 훈련 데이터(X_train)와 원-핫 인코딩된 훈련 레이블(y_train_encoded)에 대해 모델의 정확도를 평가합니다.
# evaluate 메서드는 X_train에 대한 예측을 수행하고, 이 예측과 실제 레이블(y_train_encoded)을 비교하여 훈련 정확도(train_accuracy)를 계산합니다.
# 이 정확도 값은 train_accuracy 변수에 저장됩니다.
# python
# 코드 복사
# test_accuracy = Mnist.evaluate(X_test, y_test_encoded)
# Mnist 인스턴스의 evaluate 메서드를 호출하여 테스트 데이터(X_test)와 원-핫 인코딩된 테스트 레이블(y_test_encoded)에 대해 모델의 정확도를 평가합니다.
# evaluate 메서드는 X_test에 대한 예측을 수행하고, 이 예측과 실제 레이블(y_test_encoded)을 비교하여 테스트 정확도(test_accuracy)를 계산합니다.
# 이 정확도 값은 test_accuracy 변수에 저장됩니다.
# python
# 코드 복사
# print(f"Train Accuracy: {train_accuracy:.4f}, Test Accuracy: {test_accuracy:.4f}")
# 훈련 정확도(train_accuracy)와 테스트 정확도(test_accuracy)를 포맷을 지정하여 출력합니다.
# :.4f는 소수점 이하 4자리까지 표시하도록 포맷을 지정합니다.
# 이 코드는 모델이 훈련 데이터와 테스트 데이터에 대해 얼마나 잘 작동하는지 평가하고, 그 결과를 가독성 좋게 출력하는 역할을 합니다.

# %% [markdown]
# 여기서 부터는 제가 개인적으로 궁금해서 예시 그림이랑 모델이 예측한 값이 맞는 지 확인하는 코드입니다.
# 사진을 출력하기 위해 matplotlib을 import했습니다.

# %%
import matplotlib.pyplot as plt  # 추가: 시각화를 위해 matplotlib를 임포트합니다.
def show_example_prediction(index):
    # 입력 이미지
    example_image = X_test[index].reshape(28, 28)  # 28x28 이미지로 변환

    # 모델 예측
    z1 = np.dot(X_test[index].reshape(1, -1), Mnist.w1) + Mnist.b1
    a1 = Mnist.relu(z1)
    z2 = np.dot(a1, Mnist.w2) + Mnist.b2
    a2 = Mnist.relu(z2)
    z3 = np.dot(a2, Mnist.w3) + Mnist.b3
    a3 = Mnist.softmax(z3)
    
    predicted_label = np.argmax(a3)

    # 실제 레이블
    actual_label = np.argmax(y_test_encoded[index])
    # 이미지와 예측 결과를 출력
    plt.imshow(example_image, cmap='gray')
    plt.title(f"Actual: {actual_label}, Predicted: {predicted_label}")
    plt.axis('off')
    plt.show()

# %% [markdown]
# 이 코드는 MNIST 데이터셋의 특정 이미지에 대해 모델의 예측 결과를 시각화하는 함수입니다. 각 줄을 해석해보겠습니다.
#
# python
# 코드 복사
# import matplotlib.pyplot as plt  # 추가: 시각화를 위해 matplotlib를 임포트합니다.
# matplotlib.pyplot 모듈을 plt라는 별칭으로 임포트합니다. 이는 그래프와 이미지를 시각화하는 데 사용됩니다.
# python
# 코드 복사
# def show_example_prediction(index):
# show_example_prediction이라는 이름의 함수를 정의합니다. 이 함수는 index라는 인자를 받아, 해당 인덱스에 있는 이미지에 대해 모델의 예측 결과를 시각화합니다.
# python
# 코드 복사
#     example_image = X_test[index].reshape(28, 28)  # 28x28 이미지로 변환
# X_test 배열에서 index 위치에 있는 이미지 데이터를 가져와 (28, 28) 크기로 변환하여 example_image 변수에 저장합니다. 이는 28x28 크기의 이미지를 복원하는 과정입니다.
# python
# 코드 복사
#     z1 = np.dot(X_test[index].reshape(1, -1), Mnist.w1) + Mnist.b1
# 입력 이미지(X_test[index])를 (1, -1) 형태로 변환하여 모델의 첫 번째 은닉층으로 전달합니다. 이 결과를 z1에 저장합니다. 이는 입력과 첫 번째 가중치 행렬 Mnist.w1의 내적과 첫 번째 바이어스 Mnist.b1을 더한 값입니다.
# python
# 코드 복사
#     a1 = Mnist.relu(z1)
# z1에 ReLU 활성화 함수를 적용하여 첫 번째 은닉층의 출력을 계산하고 a1에 저장합니다.
# python
# 코드 복사
#     z2 = np.dot(a1, Mnist.w2) + Mnist.b2
# 첫 번째 은닉층의 출력을 모델의 두 번째 은닉층으로 전달합니다. a1과 두 번째 가중치 행렬 Mnist.w2의 내적과 두 번째 바이어스 Mnist.b2을 더하여 z2에 저장합니다.
# python
# 코드 복사
#     a2 = Mnist.relu(z2)
# z2에 ReLU 활성화 함수를 적용하여 두 번째 은닉층의 출력을 계산하고 a2에 저장합니다.
# python
# 코드 복사
#     z3 = np.dot(a2, Mnist.w3) + Mnist.b3
# 두 번째 은닉층의 출력을 모델의 출력층으로 전달합니다. a2와 출력층 가중치 Mnist.w3의 내적과 출력층 바이어스 Mnist.b3을 더하여 z3에 저장합니다.
# python
# 코드 복사
#     a3 = Mnist.softmax(z3)
# z3에 소프트맥스 활성화 함수를 적용하여 각 클래스의 확률을 계산하고 a3에 저장합니다.
# python
# 코드 복사
#     predicted_label = np.argmax(a3)
# a3에서 가장 높은 확률을 가진 클래스의 인덱스를 predicted_label에 저장합니다. 이는 모델의 예측 레이블입니다.
# python
# 코드 복사
#     actual_label = np.argmax(y_test_encoded[index])
# y_test_encoded 배열에서 index 위치에 있는 원-핫 인코딩된 레이블에서 실제 레이블의 인덱스를 actual_label에 저장합니다.
# python
# 코드 복사
#     plt.imshow(example_image, cmap='gray')
# example_image를 회색조(cmap='gray')로 표시하여 이미지를 시각화합니다.
# python
# 코드 복사
#     plt.title(f"Actual: {actual_label}, Predicted: {predicted_label}")
# 이미지의 제목을 설정하여 실제 레이블(actual_label)과 예측 레이블(predicted_label)을 표시합니다.
# python
# 코드 복사
#     plt.axis('off')
# 이미지의 축을 숨깁니다.
# python
# 코드 복사
#     plt.show()
# 이미지를 화면에 표시합니다.
# 이 함수는 주어진 인덱스에 해당하는 이미지와 그에 대한 모델의 예측 결과를 시각화하여 모델의 성능을 직관적으로 평가할 수 있게 해줍니다.

# %%
# 예시 이미지 보기 (예: 첫 번째 테스트 이미지)
for idx in range(100):
    show_example_prediction(idx)

# %% [markdown]
# 이 코드는 show_example_prediction 함수를 사용하여 첫 번째부터 100번째까지의 테스트 이미지와 모델의 예측 결과를 시각화합니다. 각 줄을 해석해보겠습니다.
#
# python
# 코드 복사
# for idx in range(100):
# idx가 0부터 99까지의 값을 가지는 반복문을 시작합니다. 이 반복문은 총 100번 실행됩니다.
# python
# 코드 복사
#     show_example_prediction(idx)
# 현재 반복의 idx 값에 해당하는 테스트 이미지의 예측 결과를 시각화하기 위해 show_example_prediction 함수를 호출합니다.
# idx는 이미지의 인덱스를 의미하며, 이 인덱스에 해당하는 테스트 이미지와 모델의 예측 결과를 시각화합니다.
# 이 코드는 첫 번째부터 100번째까지의 테스트 이미지와 모델의 예측 결과를 연속적으로 시각화하여 모델이 어떤 이미지를 어떻게 분류하는지 살펴보는 데 유용합니다. 이 과정은 모델의 성능을 시각적으로 평가하고, 예측 결과를 직관적으로 이해하는 데 도움이 됩니다.
